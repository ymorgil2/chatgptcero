# %% [markdown]
# # Optimización $L(\theta)=\theta^2$

# %%
import torch
from IPython.display import display, Math

# parámetro inicial
theta = torch.tensor(3.0, requires_grad=True)
# optimizador, se encarga de actualizar theta
optimizer = torch.optim.SGD([theta], lr=0.1)

# bucle de optimización (30 pasos)
for step in range(30):
    # ponemos a cero los gradientes
    optimizer.zero_grad()
    # función de pérdida theta^2
    loss = theta**2
    # cálculo de gradientes
    loss.backward()
    # actualización de parámetros
    optimizer.step()
    # mostramos el progreso fancy en latex
    display(Math(
    rf"\text{{Paso }} {step + 1}: \ \theta \text{{ se ha movido a }} {theta.item():.3f},\ "
    rf"\text{{loss}} = {loss.item():.4f}"
    ))

# %% [markdown]
# # Animación del proceso de optimización $L(\theta)=\theta^2$

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# ----- 1. RUN GRADIENT DESCENT AND STORE TRAJECTORY -----

theta = torch.tensor(3.0, requires_grad=True)
optimizer = torch.optim.SGD([theta], lr=0.1)

trajectory = []
grads = []

for step in range(30):
    trajectory.append(theta.item())
    optimizer.zero_grad()
    loss = theta**2
    loss.backward()
    grads.append(theta.grad.item())   # store gradient 2θ
    optimizer.step()


trajectory = np.array(trajectory)
grads = np.array(grads)


# ----- 2. PLOT SETUP -----

fig, ax = plt.subplots(figsize=(6, 4))

# Draw parabola
x = np.linspace(-3, 3, 400)
ax.plot(x, x**2, label="f(θ)=θ²")

# Red point showing θ
point, = ax.plot([], [], 'ro', markersize=8)

# Gradient arrow
arrow = ax.arrow(0, 0, 0, 0, color='blue')

# Text info
text = ax.text(0.05, 0.9, "", transform=ax.transAxes)

ax.set_xlim(-3, 3)
ax.set_ylim(0, 10)
ax.set_xlabel("θ")
ax.set_ylabel("Loss")
ax.set_title("Optimización de θ² con gradiente descendente")
ax.legend()


# ----- 3. ANIMATION FUNCTION -----

def update(frame):
    θ = trajectory[frame]
    grad = grads[frame]

    # Update red point
    point.set_data([θ], [θ**2])

    # Remove old arrow
    global arrow
    arrow.remove()

    # Gradient arrow along x-axis
    scale = 1
    dx = - scale * grad * 0.1   # gradient points right if grad > 0, left if grad < 0
    dy = 0              # no vertical component

    arrow = ax.arrow(θ, θ**2, dx, dy, color='blue', width=0.02)

    # Update text
    text.set_text(f"step={frame}, θ={θ:.3f}, grad={grad:.3f}, loss={θ**2:.3f}")

    return point, arrow, text



anim = FuncAnimation(fig, update, frames=len(trajectory), interval=300)

plt.close()

# ----- 4. DISPLAY IN COLAB -----

HTML(anim.to_jshtml())

# %% [markdown]
# # Optimización $L(\theta)=\theta_1^2 + \theta_2^2$

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# ----- 1. RUN GRADIENT DESCENT AND STORE TRAJECTORY -----

theta = torch.tensor([2.5, -1.8], requires_grad=True)  # [theta1, theta2]
optimizer = torch.optim.SGD([theta], lr=0.15)

trajectory = []
grads = []
losses = []

for step in range(20):
    trajectory.append(theta.detach().cpu().numpy().copy())

    optimizer.zero_grad()
    loss = (theta[0] ** 2) + (theta[1] ** 2)   # theta1^2 + theta2^2
    loss.backward()

    grads.append(theta.grad.detach().cpu().numpy().copy())
    losses.append(loss.item())

    optimizer.step()

trajectory = np.array(trajectory)  # shape: (T, 2)
grads = np.array(grads)            # shape: (T, 2)
losses = np.array(losses)

# ----- 2. PLOT SETUP -----

fig, ax = plt.subplots(figsize=(6, 6))

# Contour plot of f(theta1, theta2) = theta1^2 + theta2^2
grid = np.linspace(-3, 3, 300)
X, Y = np.meshgrid(grid, grid)
Z = X**2 + Y**2
ax.contour(X, Y, Z, levels=20)

# Red point for current theta
point, = ax.plot([], [], 'ro', markersize=8)

# Gradient arrow (we'll remove & redraw each frame like your code)
arrow = ax.arrow(0, 0, 0, 0)

# Text info
text = ax.text(0.03, 0.97, "", transform=ax.transAxes, va="top")

ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
ax.set_xlabel(r"$\theta_1$")
ax.set_ylabel(r"$\theta_2$")
ax.set_title(r"Optimización de $f(\theta_1,\theta_2)=\theta_1^2+\theta_2^2$ con gradiente descendente")

# ----- 3. ANIMATION FUNCTION -----

def update(frame):
    global arrow

    th1, th2 = trajectory[frame]
    g1, g2 = grads[frame]
    loss = losses[frame]

    # Update point
    point.set_data([th1], [th2])

    # Remove old arrow
    arrow.remove()

    # Draw arrow in the *descent direction* (-grad) with scaling
    lr = 0.15
    scale = 1.0
    dx = -scale * g1 * lr
    dy = -scale * g2 * lr

    arrow = ax.arrow(th1, th2, dx, dy, width=0.03, length_includes_head=True)

    # Update text (LaTeX for thetas)
    text.set_text(
        rf"step={frame}  "
        rf"$\theta_1$={th1:.3f}, $\theta_2$={th2:.3f}  "
        rf"$\nabla f$=({g1:.3f},{g2:.3f})  "
        rf"loss={loss:.3f}"
    )

    return point, arrow, text

anim = FuncAnimation(fig, update, frames=len(trajectory), interval=250)

plt.close()
HTML(anim.to_jshtml())

# %% [markdown]
# # Ejercicio
#
# Aplica el gradiente descendente para minimizar la función $L(\theta_1,\dots,\theta_{100}) = \sum_{i=1}^{100} (\theta_i - 1)^2$. Muestra solo el loss en cada paso y el valor final de $\theta$ al terminar la optimización.
#
# Nota. Debes inicializar $\theta$ con valores aleatorios. El resultado esperado es que cada $\theta_i$ tienda a 1 al finalizar la optimización.
# - https://docs.pytorch.org/docs/stable/generated/torch.rand.html
# - `torch` funciona de manera similar a numpy, por lo que puedes usar operaciones vectorizadas como `theta + 25`, `theta ** 2`, etc.
# - `.sum()` se usar para sumar todos los elementos de un tensor.

# %%
# TODO: Ejercicio
# TODO: Ejercicio
import torch 
from IPython.display import display, Math

# parámetro inicial
theta = torch.rand(100, requires_grad=True)   # conjunto de 100 elementos decir que requiere gradiente
# optimizador, se encarga de actualizar theta
optimizer = torch.optim.SGD([theta], lr=0.1)


# bucle de optimización (30 pasos)
for step in range(30):
    # ponemos a cero los gradientes
    optimizer.zero_grad()
    # función de pérdida theta^2
    loss = ((theta - 1) ** 2).sum() # función del loss esto es el error y suele tender a cero
    # cálculo de gradientes
    loss.backward()
    # actualización de parámetros
    optimizer.step()
    # mostramos el progreso fancy en latex
    display(Math(
    rf"\text{{Paso }} {step + 1}: \ \theta \text{{ se ha movido a }},\ "
    rf"\text{{loss}} = {loss.item():.4f}"
    ))

theta # Imprimo el theta que es lo que tiende a uno
# Out:
# $\displaystyle \text{Paso } 1: \ \theta \text{ se ha movido a },\ \text{loss} = 36.5586$
# $\displaystyle \text{Paso } 2: \ \theta \text{ se ha movido a },\ \text{loss} = 23.3975$
# $\displaystyle \text{Paso } 3: \ \theta \text{ se ha movido a },\ \text{loss} = 14.9744$
# $\displaystyle \text{Paso } 4: \ \theta \text{ se ha movido a },\ \text{loss} = 9.5836$
# $\displaystyle \text{Paso } 5: \ \theta \text{ se ha movido a },\ \text{loss} = 6.1335$
# $\displaystyle \text{Paso } 6: \ \theta \text{ se ha movido a },\ \text{loss} = 3.9255$
# $\displaystyle \text{Paso } 7: \ \theta \text{ se ha movido a },\ \text{loss} = 2.5123$
# $\displaystyle \text{Paso } 8: \ \theta \text{ se ha movido a },\ \text{loss} = 1.6079$
# $\displaystyle \text{Paso } 9: \ \theta \text{ se ha movido a },\ \text{loss} = 1.0290$
# $\displaystyle \text{Paso } 10: \ \theta \text{ se ha movido a },\ \text{loss} = 0.6586$
# $\displaystyle \text{Paso } 11: \ \theta \text{ se ha movido a },\ \text{loss} = 0.4215$
# $\displaystyle \text{Paso } 12: \ \theta \text{ se ha movido a },\ \text{loss} = 0.2698$
# $\displaystyle \text{Paso } 13: \ \theta \text{ se ha movido a },\ \text{loss} = 0.1726$
# $\displaystyle \text{Paso } 14: \ \theta \text{ se ha movido a },\ \text{loss} = 0.1105$
# $\displaystyle \text{Paso } 15: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0707$
# $\displaystyle \text{Paso } 16: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0453$
# $\displaystyle \text{Paso } 17: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0290$
# $\displaystyle \text{Paso } 18: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0185$
# $\displaystyle \text{Paso } 19: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0119$
# $\displaystyle \text{Paso } 20: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0076$
# $\displaystyle \text{Paso } 21: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0049$
# $\displaystyle \text{Paso } 22: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0031$
# $\displaystyle \text{Paso } 23: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0020$
# $\displaystyle \text{Paso } 24: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0013$
# $\displaystyle \text{Paso } 25: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0008$
# $\displaystyle \text{Paso } 26: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0005$
# $\displaystyle \text{Paso } 27: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0003$
# $\displaystyle \text{Paso } 28: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0002$
# $\displaystyle \text{Paso } 29: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0001$
# $\displaystyle \text{Paso } 30: \ \theta \text{ se ha movido a },\ \text{loss} = 0.0001$
# tensor([0.9998, 1.0000, 0.9995, 0.9989, 0.9992, 1.0000, 0.9992, 0.9990, 0.9989,
#         0.9991, 0.9999, 0.9998, 0.9989, 0.9989, 1.0000, 0.9996, 0.9994, 0.9989,
#         0.9997, 1.0000, 0.9993, 0.9995, 0.9996, 0.9998, 0.9988, 0.9988, 0.9991,
#         0.9989, 0.9997, 0.9989, 0.9994, 0.9990, 0.9996, 0.9992, 0.9988, 0.9999,
#         0.9989, 0.9991, 0.9995, 0.9994, 0.9992, 0.9990, 0.9998, 0.9997, 0.9994,
#         0.9995, 0.9988, 0.9998, 0.9995, 0.9994, 0.9989, 0.9995, 0.9988, 0.9990,
#         0.9999, 0.9994, 0.9988, 0.9992, 0.9998, 0.9988, 0.9993, 0.9989, 0.9997,
#         0.9990, 0.9989, 0.9991, 0.9992, 0.9988, 0.9992, 0.9994, 0.9999, 0.9992,
#         0.9990, 0.9997, 0.9993, 0.9994, 0.9989, 0.9993, 0.9997, 0.9997, 0.9999,
#         0.9997, 0.9997, 0.9998, 0.9989, 0.9997, 0.9991, 0.9992, 0.9992, 0.9999,
#         0.9989, 0.9999, 0.9994, 0.9995, 0.9997, 0.9993, 0.9990, 0.9994, 0.9998,
#         0.9989], requires_grad=True)

# %% [markdown]
# # Ejercicio: regresión lineal con gradiente descendente
#
# El entrenamiento de la regresión lineal se puede ver como un proceso de optimización, donde el objetivo es encontrar los parámetros $\theta$ que minimizan la función de pérdida $L(\theta)$. Concretamente, $\theta=(a, b)$ representa los parámetros de la recta que queremos ajustar a los datos ($y = ax + b$), y $L(\theta)$ es la función de pérdida que mide el error entre las predicciones de la recta y los datos reales.
#
#
# $$L(a,b) = \frac{1}{n} \sum_{i=1}^{n} (y_i - (ax_i + b))^2$$
#
# Usando torch y un enfoque parecido a los ejercicios anteriores, implementa el proceso de optimización para encontrar los parámetros $a$ y $b$ que minimizan la función de pérdida $L(a,b)$ dada por la fórmula anterior. Como dataset vamos a usar el conjunto de datos de ventas de helados, que contiene dos columnas: "Temperature" (temperatura) y "Revenue" (ingresos). El objetivo es ajustar una recta a estos datos para predecir los ingresos en función de la temperatura ($x=$ Temperature, $y=$ Revenue). Finalmente, dibuja la recta ajustada junto con los datos originales para visualizar el resultado.

# %%
import pandas as pd

datos = pd.read_csv("datos-helados.csv")
datos.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
import matplotlib.pyplot as plt

datos.plot.scatter(x="Temperature", y="Revenue")
plt.title("Ventas de helados vs temperatura")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Ingresos (USD)")
# Out:
# Text(0, 0.5, 'Ingresos (USD)')

# %%
import torch

X = torch.tensor(datos["Temperature"].values, dtype=torch.float32)
y = torch.tensor(datos["Revenue"].values, dtype=torch.float32)

slope = torch.tensor(0., requires_grad=True) # a
intercept = torch.tensor(0., requires_grad=True) # b
# pista: 
# se puede hacer:
# y_pred = slope * X + intercept
# luego restar al valor esperado, elevar al cuadrado y sacar la media con torch.mean()

y_pred = slope * X + intercept #(ax+b)

loss = ((y - y_pred) ** 2).mean() #(y - (ax+b)²)

# LO mio  bueno más bien chati
#y_pred = a * x + b
#loss = ((y - y_pred) ** 2).mean()
